# %% [markdown]
# # CBR Putusan PN Malang - Narkotika dan Psikotropika
# Notebook demo untuk menjalankan pipeline Case-Based Reasoning.

# %%
import pandas as pd
from pathlib import Path

PROJECT = Path('..')
cases = pd.read_csv(PROJECT/'data/processed/cases.csv')
cases.head()

# %%
cases[['case_id','no_perkara','tanggal_putus','pasal_utama','jenis_narkotika','pidana_penjara','denda']].head(10)

# %%
import sys
sys.path.append(str(PROJECT/'src'))
from src03_import import retrieve_safe

query = 'terdakwa menguasai sabu narkotika golongan I dan dijatuhi pidana penjara'
retrieve_safe(query, k=5)

# %%
metrics = pd.read_csv(PROJECT/'data/eval/prediction_metrics.csv')
metrics

# %% [markdown]
# ## Catatan
# Gunakan notebook ini untuk demo. Untuk menjalankan ulang dari awal, jalankan script di folder `src` sesuai urutan pada README.
